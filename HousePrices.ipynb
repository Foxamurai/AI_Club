# %% [markdown]
# <a href="https://colab.research.google.com/github/Foxamurai/AI_Club/blob/main/HousePrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###В этом упражнении вы построите нейронную сеть, которая предсказывает цену дома по простой формуле.
#
# Представьте себе, что цены на жилье зависят только от количества комнат: дом стоит 500 000 + 500 000 за комнату. то есть дом с 1 спальней стоит 1 000 000, дом с 2 спальнями стоит 1 500 000 и т.д.
#
# Как вы создадите нейронную сеть, которая обучается этой зависисмости? проверьте ее, чтобы она предсказывала для дома с 7 спальнями стоимость около 4 млн.
#
# **Подсказка**: ваша сеть может работать лучше, если вы *масштабируете* цену так, как это было описано в лекциях. Не нужно давать ответ 4 000 000, лучше создать что-то, что будет предсказывать число 4 и выводить ваш ответ в миллионах.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):
    xs = np.array([1, 2, 3, 4, 5, 6,], dtype=int)  # Кол-во комнат
    ys = np.array([1, 1.5, 2., 2.5, 3, 3.5], dtype=float)  # Стоимость в млн. руб
    model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(optimizer='sgd', loss='mean_squared_error')
    model.fit(xs, ys, epochs=500)
    return model.predict(y_new)[0]

# %%
prediction = house_model([7.0])
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 215ms/step - loss: 29.3742
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 13.5990
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.2977
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9185
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3544
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6305
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2954
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1403
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0685
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0352
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0198
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0127
# ...

# %%
print(f"{np.around(prediction,2)} млн. руб")
# Out:
# [4.02] млн. руб
